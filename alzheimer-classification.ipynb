# %% [markdown]
# ### 1. Installing dependencies

# %%
import pathlib
import numpy as np
import random
import matplotlib.pyplot as plt
import os
import pandas as pd
import tensorflow as tf

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### 2. Getting the data from directory

# %%
file_path = '../Alzheimer Disease MRI/Dataset'
data_dir = pathlib.Path(file_path)
class_names = np.array(sorted([item.name for item in data_dir.glob('*')]))
print(class_names)
# Out:
# ['Mild_Demented' 'Moderate_Demented' 'Non_Demented' 'Very_Mild_Demented']

# %% [markdown]
# ### 3. Visualizing random images with labels from the data

# %%
plt.figure(figsize=(20, 20)) 
for i in range(16):
    ax = plt.subplot(4, 4, i+1)
    random_class = random.randint(0, 3)
    folder_path = file_path + '/' + class_names[random_class]
    random_image_path = folder_path + '/' + (random.sample(os.listdir(folder_path), 1)[0])
    image = plt.imread(random_image_path)
    plt.axis('off')
    plt.title(class_names[random_class], fontsize = 15, fontweight = 'bold')
    plt.imshow(image)

# %% [markdown]
# ### 4. Preparing the dataset for building CNN

# %%
SEED = 1   # maybe can do with random seed generator and compare results with different seed values in the future.
BATCH_SIZE = 32
IMG_SIZE = (128, 128)

X_train = tf.keras.preprocessing.image_dataset_from_directory(
    data_dir,
    seed = SEED,
    image_size = IMG_SIZE,
    batch_size = BATCH_SIZE,
    validation_split = 0.2,
    subset = 'training'
)

X_validation = tf.keras.preprocessing.image_dataset_from_directory(
    data_dir,
    seed = SEED,
    image_size = IMG_SIZE,
    batch_size = BATCH_SIZE,
    validation_split = 0.2,
    subset = 'validation'
)
# Out:
# Found 6400 files belonging to 4 classes.
# Using 5120 files for training.
# Found 6400 files belonging to 4 classes.
# Using 1280 files for validation.

# %% [markdown]
# ### 5. Building the model

# %%
INPUT_SHAPE = IMG_SIZE + (3,)
model = tf.keras.models.Sequential()
model.add(tf.keras.layers.Rescaling(scale=1./255, input_shape=INPUT_SHAPE))
model.add(tf.keras.layers.Conv2D(filters=16, kernel_size=(3,3), padding='same', activation='relu'))
model.add(tf.keras.layers.MaxPooling2D(pool_size=(2,2)))
model.add(tf.keras.layers.Conv2D(filters=32, kernel_size=(3,3), padding='same', activation='relu'))
model.add(tf.keras.layers.MaxPooling2D(pool_size=(2,2)))
model.add(tf.keras.layers.Conv2D(filters=64, kernel_size=(3,3), padding='same', activation='relu'))
model.add(tf.keras.layers.MaxPooling2D(pool_size=(2,2)))
model.add(tf.keras.layers.Dropout(0.20))
model.add(tf.keras.layers.Flatten())
model.add(tf.keras.layers.Dense(128, activation='relu'))
model.add(tf.keras.layers.Dense(4, activation = 'softmax'))

model.compile(
    loss='sparse_categorical_crossentropy',
    optimizer='adam',
    metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling (Rescaling)       (None, 128, 128, 3)       0
#
#  conv2d (Conv2D)             (None, 128, 128, 16)      448
#
#  max_pooling2d (MaxPooling2D  (None, 64, 64, 16)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 64, 64, 32)        4640
#
#  max_pooling2d_1 (MaxPooling  (None, 32, 32, 32)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 32, 32, 64)        18496
#
#  max_pooling2d_2 (MaxPooling  (None, 16, 16, 64)       0
#  2D)
#
#  dropout (Dropout)           (None, 16, 16, 64)        0
#
#  flatten (Flatten)           (None, 16384)             0
#
#  dense (Dense)               (None, 128)               2097280
#
#  dense_1 (Dense)             (None, 4)                 516
#
# =================================================================
# Total params: 2,121,380
# Trainable params: 2,121,380
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### 6. Fitting the model

# %%
history = model.fit(X_train, epochs = 50, validation_data=X_validation, verbose=1)
# Out:
# Epoch 1/50
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x000002119265A3A8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x000002119265A3A8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 160/160 [==============================] - ETA: 0s - loss: 1.0067 - accuracy: 0.5123WARNING:tensorflow:AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x00000211CE06E1F8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x00000211CE06E1F8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 160/160 [==============================] - 25s 152ms/step - loss: 1.0067 - accuracy: 0.5123 - val_loss: 1.0004 - val_accuracy: 0.4781
# Epoch 2/50
# 160/160 [==============================] - 25s 156ms/step - loss: 0.8546 - accuracy: 0.6078 - val_loss: 0.8505 - val_accuracy: 0.6195
# Epoch 3/50
# 160/160 [==============================] - 25s 159ms/step - loss: 0.7215 - accuracy: 0.6750 - val_loss: 0.7102 - val_accuracy: 0.6836
# Epoch 4/50
# 160/160 [==============================] - 25s 155ms/step - loss: 0.5597 - accuracy: 0.7602 - val_loss: 0.4895 - val_accuracy: 0.7852
# Epoch 5/50
# 160/160 [==============================] - 25s 154ms/step - loss: 0.3805 - accuracy: 0.8457 - val_loss: 0.4935 - val_accuracy: 0.7937
# Epoch 6/50
# 160/160 [==============================] - 25s 155ms/step - loss: 0.2903 - accuracy: 0.8848 - val_loss: 0.2421 - val_accuracy: 0.9102
# Epoch 7/50
# 160/160 [==============================] - 25s 154ms/step - loss: 0.1805 - accuracy: 0.9365 - val_loss: 0.1952 - val_accuracy: 0.9281
# Epoch 8/50
# 160/160 [==============================] - 25s 154ms/step - loss: 0.1115 - accuracy: 0.9629 - val_loss: 0.1645 - val_accuracy: 0.9500
# Epoch 9/50
# 160/160 [==============================] - 25s 158ms/step - loss: 0.0998 - accuracy: 0.9645 - val_loss: 0.1112 - val_accuracy: 0.9609
# Epoch 10/50
# 160/160 [==============================] - 25s 156ms/step - loss: 0.0733 - accuracy: 0.9752 - val_loss: 0.1091 - val_accuracy: 0.9578
# Epoch 11/50
# 160/160 [==============================] - 25s 155ms/step - loss: 0.0659 - accuracy: 0.9781 - val_loss: 0.1212 - val_accuracy: 0.9516
# Epoch 12/50
# 160/160 [==============================] - 25s 156ms/step - loss: 0.0562 - accuracy: 0.9785 - val_loss: 0.1028 - val_accuracy: 0.9711
# Epoch 13/50
# 160/160 [==============================] - 25s 155ms/step - loss: 0.0498 - accuracy: 0.9811 - val_loss: 0.0576 - val_accuracy: 0.9828
# Epoch 14/50
# 160/160 [==============================] - 25s 155ms/step - loss: 0.0337 - accuracy: 0.9893 - val_loss: 0.0606 - val_accuracy: 0.9828
# Epoch 15/50
# 160/160 [==============================] - 25s 155ms/step - loss: 0.0319 - accuracy: 0.9879 - val_loss: 0.0864 - val_accuracy: 0.9750
# Epoch 16/50
# 160/160 [==============================] - 25s 155ms/step - loss: 0.0284 - accuracy: 0.9904 - val_loss: 0.0914 - val_accuracy: 0.9750
# Epoch 17/50
# 160/160 [==============================] - 25s 155ms/step - loss: 0.0332 - accuracy: 0.9881 - val_loss: 0.0431 - val_accuracy: 0.9852
# Epoch 18/50
# 160/160 [==============================] - 25s 154ms/step - loss: 0.0201 - accuracy: 0.9926 - val_loss: 0.0933 - val_accuracy: 0.9758
# Epoch 19/50
# 160/160 [==============================] - 25s 155ms/step - loss: 0.0417 - accuracy: 0.9857 - val_loss: 0.1450 - val_accuracy: 0.9477
# Epoch 20/50
# 160/160 [==============================] - 25s 154ms/step - loss: 0.0355 - accuracy: 0.9887 - val_loss: 0.0519 - val_accuracy: 0.9883
# Epoch 21/50
# 160/160 [==============================] - 25s 154ms/step - loss: 0.0179 - accuracy: 0.9941 - val_loss: 0.0559 - val_accuracy: 0.9828
# Epoch 22/50
# 160/160 [==============================] - 25s 154ms/step - loss: 0.0226 - accuracy: 0.9920 - val_loss: 0.0572 - val_accuracy: 0.9812
# Epoch 41/50
# 160/160 [==============================] - 25s 154ms/step - loss: 0.0151 - accuracy: 0.9941 - val_loss: 0.0520 - val_accuracy: 0.9867
# Epoch 42/50
# 160/160 [==============================] - 25s 154ms/step - loss: 0.0111 - accuracy: 0.9963 - val_loss: 0.0413 - val_accuracy: 0.9914
# Epoch 43/50
# 160/160 [==============================] - 25s 154ms/step - loss: 0.0158 - accuracy: 0.9936 - val_loss: 0.0622 - val_accuracy: 0.9836
# Epoch 44/50
# 160/160 [==============================] - 25s 154ms/step - loss: 0.0164 - accuracy: 0.9949 - val_loss: 0.0483 - val_accuracy: 0.9883
# Epoch 45/50
# 160/160 [==============================] - 25s 154ms/step - loss: 0.0048 - accuracy: 0.9980 - val_loss: 0.0413 - val_accuracy: 0.9891
# Epoch 46/50
# 160/160 [==============================] - 25s 155ms/step - loss: 0.0261 - accuracy: 0.9916 - val_loss: 0.0591 - val_accuracy: 0.9844
# Epoch 47/50
# 160/160 [==============================] - 25s 155ms/step - loss: 0.0117 - accuracy: 0.9967 - val_loss: 0.1190 - val_accuracy: 0.9758
# Epoch 48/50
# 160/160 [==============================] - 25s 154ms/step - loss: 0.0015 - accuracy: 0.9996 - val_loss: 0.0396 - val_accuracy: 0.9906
# Epoch 49/50
# 160/160 [==============================] - 25s 154ms/step - loss: 0.0221 - accuracy: 0.9926 - val_loss: 0.0805 - val_accuracy: 0.9773
# Epoch 50/50
# 160/160 [==============================] - 25s 154ms/step - loss: 0.0275 - accuracy: 0.9906 - val_loss: 0.0541 - val_accuracy: 0.9852

# %% [markdown]
# ### 7. Model evaluation

# %%
model_evaluate = model.evaluate(X_validation)
print("Accuracy: %", "{:.2f}".format(model_evaluate[1]*100))
print("Loss: %", "{:.2f}".format(model_evaluate[0]*100))
# Out:
# 40/40 [==============================] - 1s 36ms/step - loss: 0.0541 - accuracy: 0.9852
# Accuracy: % 98.52
# Loss: % 5.41

# %%
df = pd.DataFrame(history.history)
ax = df.plot(figsize=(10,5), lw=3, grid='on')
ax.set_title('History per Epoch', fontsize=18, fontweight='bold')
ax.set_xlabel('Epochs', fontsize=15, fontweight='bold')
ax.plot()
# Out:
# []

# %%
plt.figure(figsize=(20, 20))
for image, label in X_validation.take(1): 
    for i in range(16):
        ax = plt.subplot(4, 4, i+1)
        img = image[i].numpy().astype("uint8")
        img = tf.expand_dims(img, axis=0)
        predicted_class = np.argmax(model.predict(img))
        plt.axis('off')
        plt.title("True Label: " + class_names[label[i]]+'\n', fontsize=12, style='italic', color='blue', loc='center')
        plt.title("Predicted Label: " + class_names[predicted_class], fontsize=12, fontweight='bold', color='green', loc='right')
        plt.imshow(image[i].numpy().astype("uint8"))
# Out:
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x00000211CE45FF78> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x00000211CE45FF78> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 20ms/step
